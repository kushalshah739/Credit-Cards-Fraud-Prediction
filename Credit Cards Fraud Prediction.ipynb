# %%
import pandas as pd #MATRIX COMPUTATION
import numpy as np #LINEAR ALGEBRA COMPUTATION
import seaborn as sns # FOR PLOTTING

# %%
dataset = pd.read_csv("C:/Users/apurva/Desktop/creditcard.csv")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Time        284807 non-null  float64
#  1   V1          284807 non-null  float64
#  2   V2          284807 non-null  float64
#  3   V3          284807 non-null  float64
#  4   V4          284807 non-null  float64
#  5   V5          284807 non-null  float64
#  6   V6          284807 non-null  float64
#  7   V7          284807 non-null  float64
#  8   V8          284807 non-null  float64
#  9   V9          284807 non-null  float64
#  10  V10         284807 non-null  float64
#  11  V11         284807 non-null  float64
#  12  V12         284807 non-null  float64
#  13  V13         284807 non-null  float64
#  14  V14         284807 non-null  float64
#  15  V15         284807 non-null  float64
#  16  V16         284807 non-null  float64
#  17  V17         284807 non-null  float64
#  18  V18         284807 non-null  float64
#  19  V19         284807 non-null  float64
#  20  V20         284807 non-null  float64
#  21  V21         284807 non-null  float64
#  22  V22         284807 non-null  float64
#  23  V23         284807 non-null  float64
#  24  V24         284807 non-null  float64
#  25  V25         284807 non-null  float64
#  26  V26         284807 non-null  float64
#  27  V27         284807 non-null  float64
#  28  V28         284807 non-null  float64
#  29  Amount      284807 non-null  float64
#  30  Fraudulent  284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
# display the first ten rows of the dataset.
dataset.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 6  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055  0.750137
# 7 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 8  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
# 9  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050 -0.069733
#
#         V26       V27       V28  Amount  Fraudulent
# 0 -0.189115  0.133558 -0.021053  149.62           0
# 1  0.125895 -0.008983  0.014724    2.69           0
# 2 -0.139097 -0.055353 -0.059752  378.66           0
# 3 -0.221929  0.062723  0.061458  123.50           0
# 4  0.502292  0.219422  0.215153   69.99           0
# 5  0.105915  0.253844  0.081080    3.67           0
# 6 -0.257237  0.034507  0.005168    4.99           0
# 7 -0.051634 -1.206921 -1.085339   40.80           0
# 8 -0.384157  0.011747  0.142404   93.20           0
# 9  0.094199  0.246219  0.083076    3.68           0
#
# [10 rows x 31 columns]

# %%
# find the number of rows and coloumns of the dataset
dataset.shape
# Out:
# (284807, 31)

# %%
dataset.isnull().sum()
# number of empty/null values
# Out:
# Time          0
# V1            0
# V2            0
# V3            0
# V4            0
# V5            0
# V6            0
# V7            0
# V8            0
# V9            0
# V10           0
# V11           0
# V12           0
# V13           0
# V14           0
# V15           0
# V16           0
# V17           0
# V18           0
# V19           0
# V20           0
# V21           0
# V22           0
# V23           0
# V24           0
# V25           0
# V26           0
# V27           0
# V28           0
# Amount        0
# Fraudulent    0
# dtype: int64

# %%
dataset.columns
# lists all coloumns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Fraudulent'],
#       dtype='object')

# %%
dataset['Fraudulent'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Fraudulent, dtype: int64

# %%
x = dataset.drop('Fraudulent',axis=1)
x
y = dataset.Fraudulent

# %%
# Before we make a machine learning model, we need to check the dataframe for Fradulent/Non-Fradulent if it is imbalanced.
# Else, the model will simply 'memorise' the pattern and allocate most transactions to be 'N' because of the majority.

import matplotlib.pyplot as plt 

sns.countplot(x='Fraudulent',data=dataset)

# %%
#clearly there is a huge imbalance for fraudulent and non-fraudulent values.
# In the next two cells, implement the undersampling library using the NearMiss() function that will undersample the exceessive Non-Fradulent (0)

from imblearn.under_sampling import NearMiss
under_sampler = NearMiss()
x_res,y_res = under_sampler.fit_sample(x,y)

# %%
from collections import Counter
print("before oversampling:",Counter(y))
print("after oversampling:",Counter(y_res))
# Out:
# before oversampling: Counter({0: 284315, 1: 492})
# after oversampling: Counter({0: 492, 1: 492})

# %%
y_res.value_counts()
# now it is balanced
# Out:
# 1    492
# 0    492
# Name: Fraudulent, dtype: int64

# %%
x_res= pd.concat([x_res,y_res],axis=1)
x_res = x_res.loc[:,~x_res.columns.duplicated()]
x_res
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 0     76866.0  1.257227  0.408096  0.319266  0.685011 -0.302937 -1.052552
# 1     76868.0  1.254775  0.375340  0.311959  0.691077 -0.343494 -1.065252
# 2     76870.0 -1.050697  1.500753  0.846326 -0.282956  0.059866 -0.561182
# 3     76866.0  1.245537  0.419648  0.312943  1.111459 -0.205612 -0.950912
# 4     76870.0  1.261137  0.304662  0.527018  0.612765 -0.411488 -0.972770
# ..        ...       ...       ...       ...       ...       ...       ...
# 979  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 980  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 981  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 982  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 983  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#            V7        V8        V9  ...       V21       V22       V23  \
# 0    0.136991 -0.245655 -0.079491  ... -0.279430 -0.770134  0.119789
# 1    0.110222 -0.222721 -0.017278  ... -0.283275 -0.803506  0.124643
# 2    0.484517  0.181547  0.081544  ... -0.335560 -0.780232 -0.027029
# 3    0.267398 -0.274685 -0.127708  ...  0.035687  0.186705 -0.107300
# 4    0.112838 -0.248052 -0.068454  ... -0.249081 -0.683649  0.126936
# ..        ...       ...       ...  ...       ...       ...       ...
# 979 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 980 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 981 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 982 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 983  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
#           V24       V25       V26       V27       V28  Amount  Fraudulent
# 0    0.360130  0.241921  0.092261 -0.018228  0.032361    1.78           0
# 1    0.354395  0.226835  0.093208 -0.021100  0.031686    2.69           0
# 2   -0.090180 -0.022896  0.091830  0.547241  0.278780    1.29           0
# 3    0.417887  0.712330 -0.330843  0.018576  0.021871    3.99           0
# 4    0.395307  0.243448  0.092344 -0.024149  0.020589    1.79           0
# ..        ...       ...       ...       ...       ...     ...         ...
# 979 -0.294885  0.537503  0.788395  0.292680  0.147968  390.00           1
# 980 -0.081049  0.521875  0.739467  0.389152  0.186637    0.76           1
# 981  0.032070 -0.739695  0.471111  0.385107  0.194361   77.89           1
# 982 -0.183659 -0.328168  0.606116  0.884876 -0.253700  245.00           1
# 983 -0.450261  0.313267 -0.289617  0.002988 -0.015309   42.53           1
#
# [984 rows x 31 columns]

# %%
sns.countplot(x='Fraudulent',data= x_res)

# %%
# We now split the dataset into 90-10 where 90% of the dataset will be used for building our model and 10% to test on.
data = x_res.sample(frac=0.90, random_state=786)
data_unseen = x_res.drop(data.index)


#data.reset_index(inplace=True, drop=True)
#data_unseen.reset_index(inplace=True, drop=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (886, 31)
# Unseen Data For Predictions: (98, 31)

# %%
# the 90% of our dataset above will further be split into 70-30 (default ratio) as a training and testing set
from pycaret.classification import *

fraud_detector = setup(data = data, target = 'Fraudulent')
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_555b19f8_ee2d_11ea_b875_e0db55e3245d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_555b19f8_ee2d_11ea_b875_e0db55e3245dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow0_col1" class="data row0 col1" >2742</td>
#             </tr>
#             <tr>
#                         <th id="T_555b19f8_ee2d_11ea_b875_e0db55e3245dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow1_col1" class="data row1 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_555b19f8_ee2d_11ea_b875_e0db55e3245dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow2_col0" class="data row2 col0" >Label Encoded</td>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_555b19f8_ee2d_11ea_b875_e0db55e3245dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow3_col1" class="data row3 col1" >(886, 31)</td>
#             </tr>
#             <tr>
#                         <th id="T_555b19f8_ee2d_11ea_b875_e0db55e3245dlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_555b19f8_ee2d_11ea_b875_e0db55e3245dlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow5_col1" class="data row5 col1" >30</td>
#             </tr>
#             <tr>
#                         <th id="T_555b19f8_ee2d_11ea_b875_e0db55e3245dlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow6_col1" class="data row6 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_555b19f8_ee2d_11ea_b875_e0db55e3245dlevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_555b19f8_ee2d_11ea_b875_e0db55e3245dlevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_555b19f8_ee2d_11ea_b875_e0db55e3245dlevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_555b19f8_ee2d_11ea_b875_e0db55e3245dlevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow10_col1" class="data row10 col1" >(886, 31)</td>
#             </tr>
#             <tr>
#                         <th id="T_555b19f8_ee2d_11ea_b875_e0db55e3245dlevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow11_col1" class="data row11 col1" >(620, 30)</td>
#             </tr>
#             <tr>
#                         <th id="T_555b19f8_ee2d_11ea_b875_e0db55e3245dlevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow12_col1" class="data row12 col1" >(266, 30)</td>
#             </tr>
#             <tr>
#                         <th id="T_555b19f8_ee2d_11ea_b875_e0db55e3245dlevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_555b19f8_ee2d_11ea_b875_e0db55e3245dlevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_555b19f8_ee2d_11ea_b875_e0db55e3245dlevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_555b19f8_ee2d_11ea_b875_e0db55e3245dlevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_555b19f8_ee2d_11ea_b875_e0db55e3245dlevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_555b19f8_ee2d_11ea_b875_e0db55e3245dlevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow18_col0" class="data row18 col0" >Transformation Method </td>
#                         <td id="T_555b19f8_ee2d_11ea_b875_e0db55e3245drow18_col1" class="data row18 col1" >None</td>
#             </tr>

# %%
# compare() function compares all exisiting machine learning algorithms and automatically computes the highest scores.
# catboost model has been blacklisted since it takes a lot of time computing and over time it can affect the performance and speed of the system.
# AUC is considered a better factor to measure performace instead of accuracy because,
# Accuracy ignores probability estimations of classification in favor of class labels
compare_models(blacklist = ['catboost'], sort = "AUC")
# Out:
# <style  type="text/css" >
#     #T_d3b73e62_ee55_11ea_8125_e0db55e3245d th {
#           text-align: left;
#     }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow0_col0 {
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow0_col1 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow0_col7 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow0_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow1_col0 {
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow1_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow1_col2 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow1_col4 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow1_col7 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow1_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow2_col0 {
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow2_col4 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow2_col7 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow2_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow3_col0 {
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow3_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow3_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow3_col4 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow3_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow3_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow3_col7 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow3_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow4_col0 {
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow4_col4 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow4_col7 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow4_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow5_col0 {
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow5_col4 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow5_col7 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow5_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow6_col0 {
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow6_col4 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow6_col7 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow6_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow7_col0 {
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow7_col4 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee55_11ea_8125_e0db55e3245drow7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_d3b73e62_ee
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=2742, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
# sample reference names of the machine learning models which will be used in the code.
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# catboost              CatBoost Classifier
#
#                                             Reference  Turbo
# ID
# lr            sklearn.linear_model.LogisticRegression   True
# knn            sklearn.neighbors.KNeighborsClassifier   True
# nb                     sklearn.naive_bayes.GaussianNB   True
# dt                sklearn.tree.DecisionTreeClassifier   True
# svm                sklearn.linear_model.SGDClassifier   True
# rbfsvm                                sklearn.svm.SVC  False
# gpc                      sklearn.gaussian_process.GPC  False
# mlp              sklearn.neural_network.MLPClassifier  False
# ridge            sklearn.linear_model.RidgeClassifier   True
# rf            sklearn.ensemble.RandomForestClassifier   True
# qda                 sklearn.discriminant_analysis.QDA   True
# ada               sklearn.ensemble.AdaBoostClassifier   True
# gbc       sklearn.ensemble.GradientBoostingClassifier   True
# lda                 sklearn.discriminant_analysis.LDA   True
# et              sklearn.ensemble.ExtraTreesClassifier   True
# xgboost                        xgboost.readthedocs.io   True
# lightgbm                github.com/microsoft/LightGBM   True
# catboost                                  catboost.ai   True

# %%
# Since the Light Gradient Boosting Machine has the best classification scores, that we will be our preferred model.

# %%
final_model = create_model('lightgbm')
# Scores are computed for the 70% TRAINING DATA SCORES (620,30)
# Out:
# <style  type="text/css" >
#     #T_b556aae8_ee56_11ea_8a75_e0db55e3245drow10_col0 {
#             background:  yellow;
#         }    #T_b556aae8_ee56_11ea_8a75_e0db55e3245drow10_col1 {
#             background:  yellow;
#         }    #T_b556aae8_ee56_11ea_8a75_e0db55e3245drow10_col2 {
#             background:  yellow;
#         }    #T_b556aae8_ee56_11ea_8a75_e0db55e3245drow10_col3 {
#             background:  yellow;
#         }    #T_b556aae8_ee56_11ea_8a75_e0db55e3245drow10_col4 {
#             background:  yellow;
#         }    #T_b556aae8_ee56_11ea_8a75_e0db55e3245drow10_col5 {
#             background:  yellow;
#         }    #T_b556aae8_ee56_11ea_8a75_e0db55e3245drow10_col6 {
#             background:  yellow;
#         }</style><table id="T_b556aae8_ee56_11ea_8a75_e0db55e3245d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b556aae8_ee56_11ea_8a75_e0db55e3245dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow0_col0" class="data row0 col0" >0.9516</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow0_col1" class="data row0 col1" >0.9834</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow0_col2" class="data row0 col2" >0.9355</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow0_col3" class="data row0 col3" >0.9667</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow0_col4" class="data row0 col4" >0.9508</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow0_col5" class="data row0 col5" >0.9032</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow0_col6" class="data row0 col6" >0.9037</td>
#             </tr>
#             <tr>
#                         <th id="T_b556aae8_ee56_11ea_8a75_e0db55e3245dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow1_col0" class="data row1 col0" >0.9839</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow1_col1" class="data row1 col1" >1.0000</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow1_col2" class="data row1 col2" >1.0000</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow1_col3" class="data row1 col3" >0.9688</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow1_col4" class="data row1 col4" >0.9841</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow1_col5" class="data row1 col5" >0.9677</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow1_col6" class="data row1 col6" >0.9682</td>
#             </tr>
#             <tr>
#                         <th id="T_b556aae8_ee56_11ea_8a75_e0db55e3245dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow2_col0" class="data row2 col0" >0.9516</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow2_col1" class="data row2 col1" >0.9948</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow2_col2" class="data row2 col2" >0.9032</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow2_col3" class="data row2 col3" >1.0000</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow2_col4" class="data row2 col4" >0.9492</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow2_col5" class="data row2 col5" >0.9032</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow2_col6" class="data row2 col6" >0.9075</td>
#             </tr>
#             <tr>
#                         <th id="T_b556aae8_ee56_11ea_8a75_e0db55e3245dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow3_col0" class="data row3 col0" >0.9677</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow3_col1" class="data row3 col1" >0.9990</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow3_col2" class="data row3 col2" >0.9355</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow3_col3" class="data row3 col3" >1.0000</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow3_col4" class="data row3 col4" >0.9667</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow3_col5" class="data row3 col5" >0.9355</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow3_col6" class="data row3 col6" >0.9374</td>
#             </tr>
#             <tr>
#                         <th id="T_b556aae8_ee56_11ea_8a75_e0db55e3245dlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow4_col0" class="data row4 col0" >0.9516</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow4_col1" class="data row4 col1" >0.9813</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow4_col2" class="data row4 col2" >0.9355</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow4_col3" class="data row4 col3" >0.9667</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow4_col4" class="data row4 col4" >0.9508</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow4_col5" class="data row4 col5" >0.9032</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow4_col6" class="data row4 col6" >0.9037</td>
#             </tr>
#             <tr>
#                         <th id="T_b556aae8_ee56_11ea_8a75_e0db55e3245dlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow5_col0" class="data row5 col0" >0.9516</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow5_col1" class="data row5 col1" >0.9917</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow5_col2" class="data row5 col2" >0.9000</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow5_col3" class="data row5 col3" >1.0000</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow5_col4" class="data row5 col4" >0.9474</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow5_col5" class="data row5 col5" >0.9028</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow5_col6" class="data row5 col6" >0.9071</td>
#             </tr>
#             <tr>
#                         <th id="T_b556aae8_ee56_11ea_8a75_e0db55e3245dlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow6_col0" class="data row6 col0" >0.9355</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow6_col1" class="data row6 col1" >0.9865</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow6_col2" class="data row6 col2" >0.9333</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow6_col3" class="data row6 col3" >0.9333</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow6_col4" class="data row6 col4" >0.9333</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e0db55e3245drow6_col5" class="data row6 col5" >0.8708</td>
#                         <td id="T_b556aae8_ee56_11ea_8a75_e

# %%
tuned_final_model = tune_model(final_model, optimize = "AUC", n_iter = 500)
# We tune the hyperparameters with the hope that the scores might improve. 
# n_iter = 500 will randomly search for hyper-parameters from 500 hyper-parameter combinations
# Out:
# <style  type="text/css" >
#     #T_df570b5a_ee56_11ea_946d_e0db55e3245drow10_col0 {
#             background:  yellow;
#         }    #T_df570b5a_ee56_11ea_946d_e0db55e3245drow10_col1 {
#             background:  yellow;
#         }    #T_df570b5a_ee56_11ea_946d_e0db55e3245drow10_col2 {
#             background:  yellow;
#         }    #T_df570b5a_ee56_11ea_946d_e0db55e3245drow10_col3 {
#             background:  yellow;
#         }    #T_df570b5a_ee56_11ea_946d_e0db55e3245drow10_col4 {
#             background:  yellow;
#         }    #T_df570b5a_ee56_11ea_946d_e0db55e3245drow10_col5 {
#             background:  yellow;
#         }    #T_df570b5a_ee56_11ea_946d_e0db55e3245drow10_col6 {
#             background:  yellow;
#         }</style><table id="T_df570b5a_ee56_11ea_946d_e0db55e3245d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_df570b5a_ee56_11ea_946d_e0db55e3245dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow0_col0" class="data row0 col0" >0.9516</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow0_col1" class="data row0 col1" >0.9834</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow0_col2" class="data row0 col2" >0.9355</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow0_col3" class="data row0 col3" >0.9667</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow0_col4" class="data row0 col4" >0.9508</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow0_col5" class="data row0 col5" >0.9032</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow0_col6" class="data row0 col6" >0.9037</td>
#             </tr>
#             <tr>
#                         <th id="T_df570b5a_ee56_11ea_946d_e0db55e3245dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow1_col0" class="data row1 col0" >0.9839</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow1_col1" class="data row1 col1" >1.0000</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow1_col2" class="data row1 col2" >1.0000</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow1_col3" class="data row1 col3" >0.9688</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow1_col4" class="data row1 col4" >0.9841</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow1_col5" class="data row1 col5" >0.9677</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow1_col6" class="data row1 col6" >0.9682</td>
#             </tr>
#             <tr>
#                         <th id="T_df570b5a_ee56_11ea_946d_e0db55e3245dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow2_col0" class="data row2 col0" >0.9677</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow2_col1" class="data row2 col1" >0.9906</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow2_col2" class="data row2 col2" >0.9355</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow2_col3" class="data row2 col3" >1.0000</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow2_col4" class="data row2 col4" >0.9667</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow2_col5" class="data row2 col5" >0.9355</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow2_col6" class="data row2 col6" >0.9374</td>
#             </tr>
#             <tr>
#                         <th id="T_df570b5a_ee56_11ea_946d_e0db55e3245dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow3_col0" class="data row3 col0" >1.0000</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow3_col1" class="data row3 col1" >1.0000</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow3_col2" class="data row3 col2" >1.0000</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow3_col3" class="data row3 col3" >1.0000</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow3_col4" class="data row3 col4" >1.0000</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow3_col5" class="data row3 col5" >1.0000</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow3_col6" class="data row3 col6" >1.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_df570b5a_ee56_11ea_946d_e0db55e3245dlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow4_col0" class="data row4 col0" >0.9355</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow4_col1" class="data row4 col1" >0.9844</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow4_col2" class="data row4 col2" >0.9355</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow4_col3" class="data row4 col3" >0.9355</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow4_col4" class="data row4 col4" >0.9355</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow4_col5" class="data row4 col5" >0.8710</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow4_col6" class="data row4 col6" >0.8710</td>
#             </tr>
#             <tr>
#                         <th id="T_df570b5a_ee56_11ea_946d_e0db55e3245dlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow5_col0" class="data row5 col0" >0.9516</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow5_col1" class="data row5 col1" >0.9938</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow5_col2" class="data row5 col2" >0.9000</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow5_col3" class="data row5 col3" >1.0000</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow5_col4" class="data row5 col4" >0.9474</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow5_col5" class="data row5 col5" >0.9028</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow5_col6" class="data row5 col6" >0.9071</td>
#             </tr>
#             <tr>
#                         <th id="T_df570b5a_ee56_11ea_946d_e0db55e3245dlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow6_col0" class="data row6 col0" >0.9355</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow6_col1" class="data row6 col1" >0.9781</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow6_col2" class="data row6 col2" >0.9333</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow6_col3" class="data row6 col3" >0.9333</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow6_col4" class="data row6 col4" >0.9333</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e0db55e3245drow6_col5" class="data row6 col5" >0.8708</td>
#                         <td id="T_df570b5a_ee56_11ea_946d_e

# %%
# To get the best hyper-parameters, print the tuned model object.
tuned_final_model
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.5, max_depth=50,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.1,
#                n_estimators=100, n_jobs=-1, num_leaves=60, objective=None,
#                random_state=2742, reg_alpha=0.2, reg_lambda=0.6, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
# For the most part here, the tuned model has better scores than the untuned model,
# so we will proceed with the tuned model (tuned_final_model)

# %%
plot_model(tuned_final_model,plot='learning')

# %%
plot_model(tuned_final_model,plot='feature')
# it seems time, amount, and v4 are the key fraud predictor factors.

# %%
plot_model(tuned_final_model,plot='confusion_matrix')

# %%
plot_model(tuned_final_model,plot='class_report')

# %%
plot_model(tuned_final_model,plot='auc')

# %%
plot_model(tuned_final_model, plot='error')

# %%
plot_model(tuned_final_model, plot='boundary')

# %%
plot_model(tuned_final_model, plot='pr')

# %%
plot_model(tuned_final_model, plot='vc')

# %%
# we will now run our final model and predict the Fraud on the test data (266,31).
final_predictions = predict_model(tuned_final_model)
# TEST SET SCORES
# Out:
#                              Model  Accuracy     AUC  Recall  Prec.      F1  \
# 0  Light Gradient Boosting Machine    0.9624  0.9923  0.9542  0.969  0.9615
#
#     Kappa     MCC
# 0  0.9248  0.9249

# %%
# Since the accuracy and the AUC of test set <= training set, this model can be considered valid.
# AUC of 0.9923 is really very good and close to the training AUC of 0.9926
final_predictions
# a detailed view of predictions on the test model (the last 3 coloumns)
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 0     35929.0 -0.850992  1.205941  0.586622  0.213649  1.319805 -1.121377
# 1     76836.0 -0.297888  1.102669  0.845990 -0.333178  0.713058  0.012503
# 2     76840.0  1.433205 -1.517794  1.542652 -0.894655 -2.143157  0.600306
# 3    140293.0  0.951025  3.252926 -5.039105  4.632411  3.014501 -1.349570
# 4    148479.0 -1.541678  3.846800 -7.604114  3.121459 -1.254924 -2.084875
# ..        ...       ...       ...       ...       ...       ...       ...
# 261   77157.0  1.316747  0.370218 -0.034555  0.490951  0.083037 -0.580881
# 262    9064.0 -3.499108  0.258555 -4.489558  4.853894 -6.974522  3.628382
# 263   61646.0 -1.522305  1.505152  0.372364  2.286869 -0.526519  0.998593
# 264   76845.0  1.141572  1.291195 -1.432900  2.058202  0.940824 -0.958274
# 265  148059.0  2.097274  0.181813 -2.186602  0.509657  0.743892 -0.882413
#
#            V7        V8        V9  ...       V23       V24       V25  \
# 0    0.920495 -0.206213 -0.618843  ... -0.382892 -0.270443  0.245283
# 1    0.621191  0.111099 -0.670599  ... -0.185141 -0.884032 -0.014651
# 2   -1.912998  0.185868 -0.365353  ... -0.097897 -0.043879  0.509737
# 3    0.980940 -1.819539 -2.099049  ...  0.358292 -1.185942 -1.286177
# 4   -2.385027  1.471140 -2.530507  ...  0.065370  0.257209 -0.693654
# ..        ...       ...       ...  ...       ...       ...       ...
# 261  0.102471 -0.178646  0.013570  ...  0.019938 -0.481877  0.345426
# 262  5.431271 -1.946734 -0.775680  ... -2.119007  0.170279 -0.393844
# 263 -1.087556 -0.027248 -0.533001  ... -0.080198 -0.253327 -0.477800
# 264  0.391154 -0.092519 -0.032829  ... -0.143911 -0.305178  0.697514
# 265  0.396835 -0.324132  0.457161  ...  0.078176 -1.101824  0.034929
#
#           V26       V27       V28   Amount  Fraudulent  Label   Score
# 0   -0.484609  0.005070  0.176426     1.00           0      0  0.0442
# 1    0.125333  0.245359  0.077360     0.99           0      0  0.0010
# 2   -0.018008  0.124289  0.030467    12.00           0      0  0.0075
# 3    0.000365  0.169662  0.108276     0.77           1      1  0.9977
# 4   -0.335702  0.577052  0.398348   122.68           1      1  0.9995
# ..        ...       ...       ...      ...         ...    ...     ...
# 261  0.144838 -0.020776  0.023308     1.29           0      0  0.0011
# 262  0.296367  1.985913 -0.900452  1809.68           1      1  0.9862
# 263  0.991740 -0.952554 -0.390364    19.04           1      1  0.9996
# 264 -0.312545  0.106247  0.125060     1.00           1      1  0.9677
# 265  0.205391 -0.058646 -0.043969    19.99           0      0  0.0019
#
# [266 rows x 33 columns]

# %%
finalize_model(tuned_final_model)
#we finalize our model thus ending the  predictive model analysis
# below are some parameters of our model which can be manipulated in the setup() function above.
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.5, max_depth=50,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.1,
#                n_estimators=100, n_jobs=-1, num_leaves=60, objective=None,
#                random_state=2742, reg_alpha=0.2, reg_lambda=0.6, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
save_model(tuned_final_model,'final_model')
#we fully confirm our model and it is ready to be deployed on foreign test sets.
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %%
#we now deploy our model on a foreign test set i.e the one we initially divided with 90-10 ratio (98,33)

new_test_set = predict_model(tuned_final_model, data = data_unseen)
new_test_set.head(98)

# our model correctly predicts the label compared to the ground truth (default Fradulent section) with a very high score
# which proves we have built a successful model.
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0    76866.0  1.245537  0.419648  0.312943  1.111459 -0.205612 -0.950912
# 1    76858.0 -1.296362  1.753951  0.852071 -0.203505  0.059821 -0.600009
# 2    76872.0  1.185048  0.222030  0.982287  1.208160 -0.810254 -0.849694
# 3    76849.0 -0.582357  1.301911  1.081054 -0.193848  0.239086 -0.453743
# 4   155536.0  0.649001 -0.603866  0.650677 -1.308588 -0.245515  1.136096
# ..       ...       ...       ...       ...       ...       ...       ...
# 93  155554.0 -1.040067  3.106703 -5.409027  3.109903 -0.887237 -2.497522
# 94  155965.0 -1.201398  4.864535 -8.328823  7.652399 -0.167445 -2.767695
# 95  158638.0 -5.976119 -7.196980 -5.388316  5.104799  4.676533 -5.566870
# 96  160537.0  0.567539  3.309385 -6.631268  6.394574 -0.054172 -2.396535
# 97  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
#
#           V7        V8        V9  ...       V23       V24       V25       V26  \
# 0   0.267398 -0.274685 -0.127708  ... -0.107300  0.417887  0.712330 -0.330843
# 1   0.571852  0.110072  0.365383  ...  0.062372  0.007162 -0.025933  0.120017
# 2  -0.207656 -0.117325  0.257281  ... -0.045647  0.722741  0.499279 -0.317238
# 3   0.667315  0.059406 -0.555683  ... -0.065644 -0.031471 -0.070571  0.077006
# 4  -0.750878 -0.026288 -2.264372  ... -0.114958 -0.389365 -0.959919  0.169118
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 93 -2.073347  0.639818 -3.013331  ... -0.184233 -0.284091  0.493467  0.732329
# 94 -3.176421  1.623279 -4.367228  ...  0.192444 -0.698588  0.025003  0.514968
# 95 -4.291180  0.876531 -1.075478  ...  0.848177 -0.269916 -1.095060 -0.710905
# 96 -2.792489  0.514811 -3.541780  ... -0.180409 -0.523271  0.645054  0.246466
# 97 -0.882850  0.697211 -2.064945  ...  0.639419 -0.294885  0.537503  0.788395
#
#          V27       V28  Amount  Fraudulent  Label   Score
# 0   0.018576  0.021871    3.99           0      0  0.0097
# 1   0.679266  0.352637    0.89           0      0  0.0014
# 2   0.046284  0.035126    5.00           0      0  0.0149
# 3   0.355409  0.144477    8.52           0      0  0.0010
# 4   0.128351 -0.015705    7.90           0      0  0.0007
# ..       ...       ...     ...         ...    ...     ...
# 93  0.675067  0.337076   94.82           1      1  0.9995
# 94  0.378105 -0.053133    0.77           1      1  0.9996
# 95  0.565846 -1.034107  296.00           1      1  0.9992
# 96  0.902675  0.473572    4.69           1      1  0.9996
# 97  0.292680  0.147968  390.00           1      1  0.9993
#
# [98 rows x 33 columns]
